# %% [markdown]
# # to transform iris data into 3 dimensions and plot a 3d chart with transformed dimensions and colour each datapoint with specific class.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_y = LabelEncoder()
o = labelencoder_y.fit_transform(df['species'])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(df.iloc[:,:-1])

#Reducing the dimensions for 3D
X.shape
# Out:
# (150, 4)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
X = pca.fit_transform(X)
X.shape
# Out:
# (150, 3)

# %%
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

# %%
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.scatter(X[:,0],X[:,1],X[:,2],c=o)
# Out:
# <img src="data:image/png;base64,..." width="640">
